# %% [markdown]
# <a href="https://colab.research.google.com/github/2403a52272-dot/nlp/blob/main/Untitled5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install nltk

# %%
import nltk

# %%
nltk.download ('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
pip install spacy

# %%
import subprocess
subprocess.run(['python', '-m', 'spacy', 'download', 'en_core_web_sm'])
# Out:
# CompletedProcess(args=['python', '-m', 'spacy', 'download', 'en_core_web_sm'], returncode=0)

# %%
import spacy
nlp = spacy.load('en_core_web_sm')

# %%
text = """Artificial Intelligence is transforming the world.
From healthcare to education, AI is improving efficiency and accuracy."""

# %%
words = text.split()
word_count = len(words)

print("Number of words:", word_count)
# Out:
# Number of words: 16
